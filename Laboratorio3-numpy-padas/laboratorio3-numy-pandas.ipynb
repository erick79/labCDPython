# %% [markdown]
# # Parte 1: Numpy:
# Para los ejercicios siguiente genere el código que considere
# para resolver el problema que se le plante
# a.
# 1) ¿Cuál es el tamaño en bytes de un array de 1000
# elementos de tipo booleano

# %%
import numpy as np

# %%
arreglo=np.ones(1000,dtype=bool)  #creamos un array de unos de tipo boleano
tamanoBytes=arreglo.itemsize * 1000
tamanoBytes
# Out:
# 1000

# %% [markdown]
# 2) Cree un array cuyos elementos sean los enteros pares en
# [1,100] y en orden decreciente. Muestre los 10 últimos
# por pantalla.

# %%
arreglo=np.arange(100,1,-2)
arreglo[-10:]
# Out:
# array([20, 18, 16, 14, 12, 10,  8,  6,  4,  2])

# %% [markdown]
# 3) Dado el array <br>
# 2 4 5 6 <br>
# 0 3 7 4 <br>
# 8 8 5 2 <br>
# 1 5 6 1 <br>
# seleccione con una instruccion el subarray de elementos <br>
# 0 3 7 4 <br>
# despues seleccione el subarray, de elementos <br>
# 2 5<br>
# 8 5

# %%
arreglo=np.array([[2,4,5,6],
         [0,3,7,4],
         [8,8,5,2],
         [1,5,6,1]
         ])
sub1=arreglo[1]  # me devuelve la fila 1
print(sub1)
sub2=arreglo[[0, 2]][:, [0, 2]]  # me devuelve filas 0 y 2 y luego las columnas de todas las filas de ese subarreglo y col 0 y 2
print(sub2)
# Out:
# [0 3 7 4]
# [[2 5]
#  [8 5]]

# %% [markdown]
# 4) Dados los arrays a = [1, 4, 2, 7] y b = [1, 3, 2, 9],
# obtenga la media aritmética de la diferencia (a-b).

# %%
a=np.array([1,4,2,7])
b=np.array([1,3,2,9])
np.mean(a-b)
# Out:
# -0.25

# %% [markdown]
# 5) tengo valores de las coordenadas x e y  en las columnas del array <br>
# 1.33   4.5 <br>
# 30.0   10.7 <br>
# 70.2   0.5  <br>
# agregue a este array las coordenadas (37.1, -3.6) muestre en pantalla las dimensiones del nuevo array

# %%
arreglo=np.array([[1.33,4.5],
        [30.0,10.7],
        [70.2,0.5]
        ])
arregloNuevo=np.append(arreglo,[37.1,-3.6])
print(arreglo)
print("las nuevas dimensiones son:",arregloNuevo.shape)
# Out:
# [[ 1.33  4.5 ]
#  [30.   10.7 ]
#  [70.2   0.5 ]]
# las nuevas dimensiones son: (8,)

# %% [markdown]
# 6) Copie el array del ejercicio anterior. Traspóngalo (.
# Agregue ahora dos nuevos pares de coordenadas: (10.8,
# 3.0) y (35.8, 12.0).

# %%
arreglo=np.array([[1.33,4.5],
        [30.0,10.7],
        [70.2,0.5]
        ])
transpuesta=arreglo.T
transpuesta
arregloNuevo=np.append(transpusta,[[10.8,3.0],[35.8,12.0]])
arregloNuevo
# Out:
# array([ 1.33, 30.  , 70.2 ,  4.5 , 10.7 ,  0.5 , 10.8 ,  3.  , 35.8 ,
#        12.  ])

# %% [markdown]
# # Parte 2: Exploración y Minería de Datos:

# %% [markdown]
# Cargar el archivo nucleospoblacion.csv

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
datasetOriginal=pd.read_csv("nucleospoblacion.csv")
datasetOriginal.head(5)
# Out:
#    FID  OBJECTID     Texto  Poblacion  CodMun Municipio  CodProvin  \
# 0    0         1   Agüimes    29431.0   35002   Agüimes         35
# 1    1         2   Antigua    10458.0   35003   Antigua         35
# 2    2         3  Arrecife    58156.0   35004  Arrecife         35
# 3    3         4    Arucas    36745.0   35006    Arucas         35
# 4    4         5    Gáldar    24473.0   35009    Gáldar         35
#
#     Provincia          X          Y
# 0  Las Palmas -15.446012  27.900542
# 1  Las Palmas -14.013301  28.418966
# 2  Las Palmas -13.551451  28.960649
# 3  Las Palmas -15.521512  28.117496
# 4  Las Palmas -15.654111  28.143873

# %% [markdown]
# 1) ¿Cuántos Municipios tienen más de 100000
# habitantes?

# %%
datasetOriginal.count
len(datasetOriginal[(datasetOriginal['Poblacion']>1000000)])
# Out:
# 2

# %% [markdown]
# Realice una gráfica de barras sobre la polbación de cada
# ciudad, ordenela de menor a mayo y responda:
# a. ¿Cuál es la segunda ciudad más poblada?
# b. ¿Qué posición ocupa Granada en el ranking de
# las ciudades más pobladas?

# %%
dataOrdenada = datasetOriginal.sort_values(by='Poblacion')

# Configurando la grafica de barras
plt.figure(figsize=(10, 6))
plt.barh(dataOrdenada['Municipio'], dataOrdenada['Poblacion'], color='blue')
plt.xlabel('Población')
plt.ylabel('Municipio')
plt.title('Grafica de poblacion vrs municipio')
plt.grid(axis='x')
plt.show() #muetra la grafica

# %% [markdown]
# Cual es la segunda ciudad mas poblada:

# %%
dataOrdenada.iloc[len(dataOrdenada)-2]['Municipio']
# Out:
# 'Barcelona'

# %%
Que posicion ocupa Granada en el ranking de las ciudades mas pobladas

# %%
# primero ordenamos por poblacion de mayor a menor para luego ver en que posicion del ranking queda
dataDescendente = dataOrdenada.sort_values(by='Poblacion', ascending=False)

# %%
dataDescendente
# Out:
#      FID  OBJECTID           Texto  Poblacion  CodMun       Municipio  \
# 355  355       356          Madrid  3273049.0   28079          Madrid
# 623  623       624       Barcelona  1619337.0    8019       Barcelona
# 561  561       562        Valencia   809267.0   46250        Valencia
# 492  492       493         Sevilla   704198.0   41091         Sevilla
# 591  591       592        Zaragoza   675121.0   50297        Zaragoza
# ..   ...       ...             ...        ...     ...             ...
# 525  525       526           Buñol    10077.0   46077           Buñol
# 746  746       747  Premià de Dalt    10064.0    8230  Premià de Dalt
# 168  168       169         Amurrio    10050.0    1002         Amurrio
# 115  115       116  Caldas de Reis    10045.0   36005  Caldas de Reis
# 307  307       308       Zumarraga    10037.0   20080       Zumarraga
#
#      CodProvin          Provincia         X          Y
# 355         28             Madrid -3.703797  40.416630
# ...

# %%
#ranking grada
dataDescendente[dataDescendente['Municipio'] == 'Granada'].index[0] + 1
# Out:
# 273

# %% [markdown]
# 3) Cuántos municipios de Extremadura tienen más de 5000
# habitantes?.

# %% [markdown]
# 4)Cuál es el municipio situado más al Norte? (Usar el
# valor de la coordenada "Y" que representa la latitud en
# grados). Proporcione también la provincia a la que
# pertenece y su población

# %%
# Encontrar el municipio más al norte encontramos el max de cordenada y guardamos el registro
coordenadaAlta = datasetOriginal.loc[datasetOriginal['Y'].idxmax()]
# de registro obtenido mostramos el municipio
print("El municipio más al norte es:", coordenadaAlta['Municipio'])
# Out:
# El municipio más al norte es: Viveiro

# %% [markdown]
# 5) Obtenga la media, mediana, desviación estándar, valor
# máximo y valor mínimo de la población de los municipios
# de la provincia de Granada

# %%
# filtramoslos municipios de granada
dataGranada = datasetOriginal[datasetOriginal['Provincia'] == 'Granada']

media = dataGranada['Poblacion'].mean()
mediana = dataGranada['Poblacion'].median()
desviacionStandard = dataGranada['Poblacion'].std()
maximo = dataGranada['Poblacion'].max()
minimo = dataGranada['Poblacion'].min()
print(f"media={media}")
print(f"mediana={mediana}")
print(f"desviacion={desviacionStandard}")
print(f"maximo={maximo}")
print(f"minimo={minimo}")
# Out:
# media=30217.85
# mediana=17526.0
# desviacion=50355.49171459277
# maximo=239154.0
# minimo=10386.0

# %% [markdown]
# 6) Realice un histograma con la población de los
# Municipios para cada una de las provincias.

# %%
plt.figure(figsize=(12, 8))
for provincia, datos in datasetOriginal.groupby('Provincia'):
    plt.hist(datos['Poblacion'], bins=20, alpha=0.7, label=provincia)

plt.xlabel('POBLACION')
plt.ylabel('PROVINCIA')
plt.title('POBLACION VRS PROVINCIA')
plt.legend()
plt.show()

# %% [markdown]
# 7) Seleccione al azar cincuenta municipios diferentes de
# entre los diponibles en el archivo. Asegúrese de que no
# se repitan. ¿Luego calcule el promedio de la población y
# la desviación estándar de esto 50 municipios?

# %%
# CREAMOS UN DATASET CON 50 MUNICIPIOS AL AZAR
dataset50 = datasetOriginal.sample(n=50, replace=False)

#con el dataset nuevo de los 50 municipios calculamos promedio y desviacion standard
promedio = dataset50['Poblacion'].mean()
print(f"el promedio de poblacion es={promedio}")
desviacion = dataset50['Poblacion'].std()
print(f"la desviacion es={desviacion}")
# Out:
# el promedio de poblacion es=43883.06
# la desviacion es=117203.52125193791

# %% [markdown]
# 8) Determine los nombres de los Municipios más cercano y
# más lejano a Madrid. Para ello debe calcular la
# distancia en todos ellos y Madrid. No considere a Madrid
# en el análisis ya que la distancia sería cero

# %%
# Coordenadas de Madrid (latitud y longitud)
latitud=datasetOriginal[datasetOriginal['Municipio'] == 'Madrid'].X
print(f"latitud madrid={latitud}")
longitud=datasetOriginal[datasetOriginal['Municipio'] == 'Madrid'].Y
print(f"latitud madrid={longitud}")

# Calcular las distancias entre Madrid y cada municipio y agregamos esa columna al data set
datasetOriginal['Distancia'] = np.sqrt((datasetOriginal['X'] - latitud)**2 + (datasetOriginal['Y'] - longitud)**2)
valor=datasetOriginal['X']
valor
# Out:
# latitud madrid=355   -3.703797
# Name: X, dtype: float64
# latitud madrid=355    40.41663
# Name: Y, dtype: float64
# 0     -15.446012
# 1     -14.013301
# 2     -13.551451
# 3     -15.521512
# 4     -15.654111
#          ...
# 847    -1.124304
# 848    -1.202069
# 849    -1.130564
# 850    -3.948364
# 851     0.012911
# Name: X, Length: 852, dtype: float64
